# %%
import pandas as pd
import finnhub
finnhub_client = finnhub.Client(api_key="cp498o1r01qs3666htc0cp498o1r01qs3666htcg")
news = finnhub_client.company_news('AAPL', _from="2024-01-15", to="2024-03-31")
df = pd.DataFrame(news)
display(df)
# Out:
#     category    datetime                                           headline  \
# 0    company  1711922082  Investing Is The Priority, Now I See Trades In...
# 1    company  1711905420  Forget Apple: 2 Artificial Intelligence (AI) S...
# 2    company  1711895445  Apple's antitrust fight could threaten its sea...
# 3    company  1711889700  Lightly-regulated techs may be a tempting targ...
# 4    company  1711886400  Spring Cleaning: 3 Stocks to Say Goodbye to Ri...
# ..       ...         ...                                                ...
# 213  company  1711451640  These 2 "Magnificent Seven" Stocks Dominate Th...
# 214  company  1711450800  1 Unstoppable Stock That Could Join Microsoft,...
# 215  company  1711449029  3 ways Apple’s monopoly lawsuit could change t...
# 216  company  1711448096  Apple Should Make Better Decisions To Ensure T...
# 217  company  1711447432  The Real Reason Why Google Is Lagging: The Bin...
#
#             id                                              image related  \
# 0    126771251  https://media.gettyimages.com/id/1705807460/ph...    AAPL
# 1    126769598  https://g.foolcdn.com/editorial/images/767431/...    AAPL
# 2    126769599  https://s.yimg.com/ny/api/res/1.2/TiFAeANai35V...    AAPL
# 3    126769089                                                       AAPL
# 4    126767363  https://g.foolcdn.com/editorial/images/770708/...    AAPL
# ..         ...                                                ...     ...
# 213  126687675  https://g.foolcdn.com/editorial/images/770547/...    AAPL
# 214  126687139  https://g.foolcdn.com/editorial/images/770368/...    AAPL
# 215  126695467  https://media.cnn.com/api/v1/images/stellar/pr...    AAPL
# 216  126688584  https://static.seekingalpha.com/cdn/s3/uploads...    AAPL
# 217  126688464  https://media.gettyimages.com/id/1488911645/ph...    AAPL
#
#             source                                            summary  \
# 0     SeekingAlpha  Investing in small caps and various sectors st...
# 1            Yahoo  Apple isn't what it once was. Here are two AI ...
# 2            Yahoo  Apple's antitrust battle with the DOJ could pr...
# 3    Seeking Alpha  Looking for stock market analysis and research...
# 4            Yahoo  Investors might want to move on from these sto...
# ..             ...                                                ...
# 213          Yahoo  Known more for delivering capital gains, Micro...
# 214          Yahoo  A long track record of expertise will propel t...
# 215          Yahoo  When Apple launched its first Mac computer in ...
# 216   SeekingAlpha  Apple has an excellent business, dominating th...
# 217   SeekingAlpha  Google's stock performance has lagged behind i...
#
#                                                    url
# 0    https://finnhub.io/api/news?id=aeee822ee3028b5...
# 1    https://finnhub.io/api/news?id=afeae4eb8eafc36...
# 2    https://finnhub.io/api/news?id=d6a80127aa8716a...
# 3    https://finnhub.io/api/news?id=7c2f02f621c9f1e...
# 4    https://finnhub.io/api/news?id=ab100111551ca98...
# ..                                                 ...
# 213  https://finnhub.io/api/news?id=136ce410dc298b9...
# 214  https://finnhub.io/api/news?id=8ba15c28bbc6b79...
# 215  https://finnhub.io/api/news?id=5115b7c1920bc80...
# 216  https://finnhub.io/api/news?id=815d3b41454b5e6...
# 217  https://finnhub.io/api/news?id=c815960dfdfd30e...
#
# [218 rows x 9 columns]
